# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

warnings.filterwarnings('ignore')

sns.set()

# %% [markdown]
# ## Data preprocessing

# %%
books = pd.read_csv('books.csv')

ratings = pd.read_csv('ratings.csv')

# %%
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books.describe()
# Out:
#                 id       book_id  best_book_id       work_id   books_count  \
# count  10000.00000  1.000000e+04  1.000000e+04  1.000000e+04  10000.000000
# mean    5000.50000  5.264697e+06  5.471214e+06  8.646183e+06     75.712700
# std     2886.89568  7.575462e+06  7.827330e+06  1.175106e+07    170.470728
# min        1.00000  1.000000e+00  1.000000e+00  8.700000e+01      1.000000
# 25%     2500.75000  4.627575e+04  4.791175e+04  1.008841e+06     23.000000
# 50%     5000.50000  3.949655e+05  4.251235e+05  2.719524e+06     40.000000
# 75%     7500.25000  9.382225e+06  9.636112e+06  1.451775e+07     67.000000
# max    10000.00000  3.328864e+07  3.553423e+07  5.639960e+07   3455.000000
#
#              isbn13  original_publication_year  average_rating  ratings_count  \
# count  9.415000e+03                9979.000000    10000.000000   1.000000e+04
# mean   9.755044e+12                1981.987674        4.002191   5.400124e+04
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 1 to 10000
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         10000 non-null  int64
#  1   book_id                    10000 non-null  int64
#  2   best_book_id               10000 non-null  int64
#  3   work_id                    10000 non-null  int64
#  4   books_count                10000 non-null  int64
#  5   isbn                       9300 non-null   object
#  6   isbn13                     9415 non-null   float64
#  7   authors                    10000 non-null  object
#  8   original_publication_year  9979 non-null   float64
#  9   original_title             9415 non-null   object
#  10  title                      10000 non-null  object
#  11  language_code              8916 non-null   object
#  12  average_rating             10000 non-null  float64
# ...

# %%
books.head() #Bring the first five rows.
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 1   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 2   2        3             3  4640799          491  439554934  9.780440e+12
# 3   3    41865         41865  3212258          226  316015849  9.780316e+12
# 4   4     2657          2657  3275794          487   61120081  9.780061e+12
# 5   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 1              Suzanne Collins                     2008.0
# 2  J.K. Rowling, Mary GrandPré                     1997.0
# 3              Stephenie Meyer                     2005.0
# 4                   Harper Lee                     1960.0
# 5          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 1                          The Hunger Games  ...       4780653
# ...

# %%
books.tail(3) #Bring the last five rows.
# Out:
#           id  book_id  best_book_id   work_id  books_count        isbn  \
# 9998    9998    77431         77431   2393986           60  039330762X
# 9999    9999  8565083       8565083  13433613            7    61711527
# 10000  10000     8914          8914     11817           31   375700455
#
#              isbn13          authors  original_publication_year  \
# 9998   9.780393e+12  Patrick O'Brian                     1977.0
# 9999   9.780062e+12  Peggy Orenstein                     2011.0
# 10000  9.780376e+12      John Keegan                     1998.0
#
#                                           original_title  ... ratings_count  \
# 9998                               The Mauritius Command  ...          9421
# 9999   Cinderella Ate My Daughter: Dispatches from th...  ...         11279
# 10000                                The First World War  ...          9162
#
#       work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# ...

# %%
books.values
# Out:
# array([[1, 2767052, 2767052, ..., 2706317,
#         'https://images.gr-assets.com/books/1447303603m/2767052.jpg',
#         'https://images.gr-assets.com/books/1447303603s/2767052.jpg'],
#        [2, 3, 3, ..., 3011543,
#         'https://images.gr-assets.com/books/1474154022m/3.jpg',
#         'https://images.gr-assets.com/books/1474154022s/3.jpg'],
#        [3, 41865, 41865, ..., 1355439,
#         'https://images.gr-assets.com/books/1361039443m/41865.jpg',
#         'https://images.gr-assets.com/books/1361039443s/41865.jpg'],
#        ...,
#        [9998, 77431, 77431, ..., 5180,
#         'https://images.gr-assets.com/books/1455373531m/77431.jpg',
#         'https://images.gr-assets.com/books/1455373531s/77431.jpg'],
#        [9999, 8565083, 8565083, ..., 2375,
#         'https://images.gr-assets.com/books/1279214118m/8565083.jpg',
#         'https://images.gr-assets.com/books/1279214118s/8565083.jpg'],
#        [10000, 8914, 8914, ..., 3069,
# ...

# %% [markdown]
# ### 1) Set the index from 1

# %%
books.index=books.index+1
books
# Out:
#           id  book_id  best_book_id   work_id  books_count        isbn  \
# 1          1  2767052       2767052   2792775          272   439023483
# 2          2        3             3   4640799          491   439554934
# 3          3    41865         41865   3212258          226   316015849
# 4          4     2657          2657   3275794          487    61120081
# 5          5     4671          4671    245494         1356   743273567
# ...      ...      ...           ...       ...          ...         ...
# 9996    9996  7130616       7130616   7392860           19   441019455
# 9997    9997   208324        208324   1084709           19  067973371X
# 9998    9998    77431         77431   2393986           60  039330762X
# 9999    9999  8565083       8565083  13433613            7    61711527
# 10000  10000     8914          8914     11817           31   375700455
#
#              isbn13                      authors  original_publication_year  \
# ...

# %% [markdown]
# ### 2) Select Data

# %%
books[['original_title','authors']] #Select the column.
# Out:
#                                           original_title  \
# 1                                       The Hunger Games
# 2               Harry Potter and the Philosopher's Stone
# 3                                               Twilight
# 4                                  To Kill a Mockingbird
# 5                                       The Great Gatsby
# ...                                                  ...
# 9996                                          Bayou Moon
# 9997                                    Means of Ascent
# 9998                               The Mauritius Command
# 9999   Cinderella Ate My Daughter: Dispatches from th...
# 10000                                The First World War
#
#                            authors
# 1                  Suzanne Collins
# 2      J.K. Rowling, Mary GrandPré
# 3                  Stephenie Meyer
# 4                       Harper Lee
# 5              F. Scott Fitzgerald
# ...                            ...
# ...

# %%
books['authors'][0:3]# Select the column data number
# Out:
# 1                Suzanne Collins
# 2    J.K. Rowling, Mary GrandPré
# 3                Stephenie Meyer
# Name: authors, dtype: object

# %%
books.loc[2] # Full data corresponding to index number 2
# Out:
# id                                                                           2
# book_id                                                                      3
# best_book_id                                                                 3
# work_id                                                                4640799
# books_count                                                                491
# isbn                                                                 439554934
# isbn13                                                         9780439554930.0
# authors                                            J.K. Rowling, Mary GrandPré
# original_publication_year                                               1997.0
# original_title                        Harry Potter and the Philosopher's Stone
# title                        Harry Potter and the Sorcerer's Stone (Harry P...
# language_code                                                              eng
# ...

# %%
filt = (books['ratings_count']>50000) # Only data that meets the condition
books[filt]
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 1        1   2767052       2767052   2792775          272   439023483
# 2        2         3             3   4640799          491   439554934
# 3        3     41865         41865   3212258          226   316015849
# 4        4      2657          2657   3275794          487    61120081
# 5        5      4671          4671    245494         1356   743273567
# ...    ...       ...           ...       ...          ...         ...
# 3345  3345  19547856      19547856  27679579           55    62348671
# 3384  3384  12351649      12351649  17912072           15         NaN
# 3422  3422  16070521      16070521  21863888            1         NaN
# 3436  3436  20898019      20898019  41250341           21  078519021X
# 7373  7373  23766634      23766634  25126752           18  1408857901
#
#             isbn13                           authors  \
# 1     9.780439e+12                   Suzanne Collins
# ...

# %% [markdown]
# ### 3) Checking null values

# %%
books.fillna('')
# Out:
#           id  book_id  best_book_id   work_id  books_count        isbn  \
# 1          1  2767052       2767052   2792775          272   439023483
# 2          2        3             3   4640799          491   439554934
# 3          3    41865         41865   3212258          226   316015849
# 4          4     2657          2657   3275794          487    61120081
# 5          5     4671          4671    245494         1356   743273567
# ...      ...      ...           ...       ...          ...         ...
# 9996    9996  7130616       7130616   7392860           19   441019455
# 9997    9997   208324        208324   1084709           19  067973371X
# 9998    9998    77431         77431   2393986           60  039330762X
# 9999    9999  8565083       8565083  13433613            7    61711527
# 10000  10000     8914          8914     11817           31   375700455
#
#                 isbn13                      authors original_publication_year  \
# ...

# %%
books.dropna(inplace=True) #Clear data including null
books
# Out:
#         id  book_id  best_book_id   work_id  books_count        isbn  \
# 1        1  2767052       2767052   2792775          272   439023483
# 2        2        3             3   4640799          491   439554934
# 3        3    41865         41865   3212258          226   316015849
# 4        4     2657          2657   3275794          487    61120081
# 5        5     4671          4671    245494         1356   743273567
# ...    ...      ...           ...       ...          ...         ...
# 9995  9995    15613         15613   2764239          199  1416523723
# 9996  9996  7130616       7130616   7392860           19   441019455
# 9997  9997   208324        208324   1084709           19  067973371X
# 9998  9998    77431         77431   2393986           60  039330762X
# 9999  9999  8565083       8565083  13433613            7    61711527
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books = pd.read_csv('books.csv')
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books.dropna(axis='index',how='any') #Delete row with one or more nan
# Out:
#         id  book_id  best_book_id   work_id  books_count        isbn  \
# 0        1  2767052       2767052   2792775          272   439023483
# 1        2        3             3   4640799          491   439554934
# 2        3    41865         41865   3212258          226   316015849
# 3        4     2657          2657   3275794          487    61120081
# 4        5     4671          4671    245494         1356   743273567
# ...    ...      ...           ...       ...          ...         ...
# 9994  9995    15613         15613   2764239          199  1416523723
# 9995  9996  7130616       7130616   7392860           19   441019455
# 9996  9997   208324        208324   1084709           19  067973371X
# 9997  9998    77431         77431   2393986           60  039330762X
# 9998  9999  8565083       8565083  13433613            7    61711527
#
#             isbn13                      authors  original_publication_year  \
# ...

# %% [markdown]
# ### Sort Data

# %%
books.sort_values('ratings_count',ascending=False) #descending order by ratings_count
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 0        1   2767052       2767052   2792775          272   439023483
# 1        2         3             3   4640799          491   439554934
# 2        3     41865         41865   3212258          226   316015849
# 3        4      2657          2657   3275794          487    61120081
# 4        5      4671          4671    245494         1356   743273567
# ...    ...       ...           ...       ...          ...         ...
# 7802  7803  22931009      22351456  14286509           67         NaN
# 9113  9114    132314        132314  56399597           87  040405109X
# 6771  6772    716696        716696   1231363          777         NaN
# 8945  8946     46292         46292     45423           91  9646534783
# 7638  7639    192510        192510    186149           91  964913980X
#
#             isbn13                                authors  \
# 0     9.780439e+12                        Suzanne Collins
# ...

# %% [markdown]
# ### 4) Modifying data

# %%
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books['original_title'] = books['original_title'].str.upper() #Title is capitalized
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %% [markdown]
# ### 5) grouping

# %%
books = pd.read_csv('books.csv')

# %%
#You can know the rating average of each writer.
books.groupby('authors')[['ratings_1','ratings_2','ratings_3','ratings_4','ratings_5']].mean()
# Out:
#                                ratings_1    ratings_2  ratings_3  ratings_4  \
# authors
# A. Manette Ansay                  1051.0  3431.000000     9384.0     7412.0
# A. Meredith Walters                650.0  1414.000000     5077.5     9096.0
# A.A. Milne, Ernest H. Shepard      716.5  1507.333333     8492.5    18206.5
# A.C. Gaughen                       669.0  1196.000000     4074.0     7024.0
# A.G. Howard                        893.0  1726.000000     5040.5     9100.0
# ...                                  ...          ...        ...        ...
# منى المرشود                       1105.0  1308.000000     2629.0     4143.0
# نور عبدالمجيد                      343.0   570.000000     1342.0     2331.0
# ياسر حارب                         1213.0  2085.000000     4127.0     4232.0
# يوسف زيدان                        1505.0  2143.000000     4664.5     8002.0
# يوسف زيدان, Youssef Ziedan         707.0  1554.500000     3769.0     3425.5
#
#                                   ratings_5
# ...

# %%
ratings.isna().sum()
# Out:
# book_id    0
# user_id    0
# rating     0
# dtype: int64
